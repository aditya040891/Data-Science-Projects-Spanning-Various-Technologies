# %% [markdown]
# ## Lists and Dictionaries

# %%
[1, 2, 3]
# Out:
# [1, 2, 3]

# %%
['Hello', 1, 2, 3]
# Out:
# ['Hello', 1, 2, 3]

# %%
['Hello', [1,2,3]]
# Out:
# ['Hello', [1, 2, 3]]

# %%
my_list = ['a', 'b', 'c']

# %%
my_list
# Out:
# ['a', 'b', 'c']

# %%
my_list[0]
# Out:
# 'a'

# %%
my_list[2]
# Out:
# 'c'

# %%
len(my_list)
# Out:
# 3

# %%
my_list[-1]
# Out:
# 'c'

# %%
['a', 'b', 'c'] + ['d', 'e', 'f']
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
[0] * 6
# Out:
# [0, 0, 0, 0, 0, 0]

# %%
[1, 2, 3] * 2
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
my_list
# Out:
# ['a', 'b', 'c']

# %%
my_list[1:]
# Out:
# ['b', 'c']

# %%
my_list = my_list + ['d', 'e', 'f', 'g']

# %%
my_list[1:]
# Out:
# ['b', 'c', 'd', 'e', 'f', 'g']

# %%
my_list, my_list[2:5]
# Out:
# (['a', 'b', 'c', 'd', 'e', 'f', 'g'], ['c', 'd', 'e'])

# %%
my_list[3:5]
# Out:
# ['d', 'e']

# %%
num_list = [1, 2, 3, 4]

# %%
num_list.append("A")

# %%
num_list
# Out:
# [1, 2, 3, 4, 'A']

# %%
num_list.append("Z")

# %%
num_list
# Out:
# [1, 2, 3, 4, 'A', 'Z']

# %%
left = [1, 2, 3, 4]
right = ['A', 'B', 'C', 'D']

# %%
left.extend(right)

# %%
left
# Out:
# [1, 2, 3, 4, 'A', 'B', 'C', 'D']

# %%
left.pop()
# Out:
# 'D'

# %%
left
# Out:
# [1, 2, 3, 4, 'A', 'B', 'C']

# %%
alpha_c = left.pop()
alpha_c
# Out:
# 'C'

# %%
left
# Out:
# [1, 2, 3, 4, 'A', 'B']

# %%
nest = [1, 2, 3, [4, 5, ['find me', 2, 4, 6]]]

# %%
nest[3]
# Out:
# [4, 5, ['find me', 2, 4, 6]]

# %%
nest[3][2]
# Out:
# ['find me', 2, 4, 6]

# %%
nest[3][2][0]
# Out:
# 'find me'

# %%
my_list
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
my_list[3]
# Out:
# 'd'

# %%
my_list[3] = 'new variable'
my_list
# Out:
# ['a', 'b', 'c', 'new variable', 'e', 'f', 'g']

# %% [markdown]
# #### Dictionaries

# %%
d = {'key':'value'}
d2 = dict(key='value')

# %%
d
# Out:
# {'key': 'value'}

# %%
d2
# Out:
# {'key': 'value'}

# %%
d['key']
# Out:
# 'value'

# %%
my_data = dict(name='Aditya',
              dog = False,
              cat = True,
              age = 30,
              family = ['mother', 'father', 'wife', 'son'])

# %%
my_data
# Out:
# {'name': 'Aditya',
#  'dog': False,
#  'cat': True,
#  'age': 30,
#  'family': ['mother', 'father', 'wife', 'son']}

# %%
my_data['name']
# Out:
# 'Aditya'

# %%
my_data['family'][2]
# Out:
# 'wife'

# %%
my_data = dict(name='Aditya',
              dog = False,
              cat = True,
              age = 30,
              family = {'father': 'Dad', 'mother':'mom', 'wife':'Wifey'})

# %%
my_data
# Out:
# {'name': 'Aditya',
#  'dog': False,
#  'cat': True,
#  'age': 30,
#  'family': {'father': 'Dad', 'mother': 'mom', 'wife': 'Wifey'}}

# %%
my_data['family']
# Out:
# {'father': 'Dad', 'mother': 'mom', 'wife': 'Wifey'}

# %%
my_data['family']['father']
# Out:
# 'Dad'
