# %% [markdown]
# ## Python Basics: Numbers, Strings, Printings

# %%
2+3
# Out:
# 5

# %%
3*3
# Out:
# 9

# %%
1/4
# Out:
# 0.25

# %%
2**4
# Out:
# 16

# %%
4 % 2 # Mod , remainder
# Out:
# 0

# %%
5 % 2
# Out:
# 1

# %%
(2+5) * (3-8)
# Out:
# -35

# %% [markdown]
# #### Variable Assignment

# %%
x = 2  # Assignment operator
y = 5

# %%
x
# Out:
# 2

# %%
y
# Out:
# 5

# %%
x + y
# Out:
# 7

# %%
x - y
# Out:
# -3

# %% [markdown]
# #### Strings

# %%
'Single Quotes!'
# Out:
# 'Single Quotes!'

# %%
"Double Quotes"
# Out:
# 'Double Quotes'

# %%
"I do not like the snow!"
# Out:
# 'I do not like the snow!'

# %%
'I don't like the snow'
# Out:
#   Cell In[16], line 1
#     'I don't like the snow'
#                           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'I don\'t like the snow'
# Out:
# "I don't like the snow"

# %% [markdown]
# #### Printing

# %%
print("Hello YouTube!")
# Out:
# Hello YouTube!

# %%
name = "Aditya"
print("Hello", name)
# Out:
# Hello Aditya

# %%
age = 30
name = "John"
print(f"{name} is {age} years old.")
print(f"{name} will be {age + 5} years old in 5 years.")
# Out:
# John is 30 years old.
# John will be 35 years old in 5 years.
